# %%
import os
import pandas as pd
import pdfplumber

# %%
df = pd.read_csv('./alumnos-filtrados-20250826-1548 - alumnos-filtrados-20250826-1548.csv', on_bad_lines="skip", dtype ="str")
df.fillna("", inplace=True)

# %%
df
# Out:
#         id    matrícula             nombre   apellido_paterno  \
# 0        1   DCM0103001        María Elena             Acosta
# 1        2   DCM0309022             Manuel             Arroyo
# 2        3  DCTA0303001           Gilberto            Badillo
# 3        4   DCM0103002         Olga Lilia             Arenas
# 4        5   MCM0509011           Eutiquio  Barrientos Juárez
# ...    ...          ...                ...                ...
# 2906  3528   DCM2508012             Daniel            Chavira
# 2907  3530   DCM2508013      Erick Alfredo             Fraile
# 2908  3532   DCM2508014  Isaac Maximiliano              López
# 2909  3534   DCM2508015    Cecilia Azmavet             García
# 2910  3536   DCM2508016   Mariel Alejandra               Lara
#
#      apellido_materno  nacimiento edad género  \
# 0              Lomeli  14/06/2022    3      F
# 1             Albiter  14/06/2022    3
# 2                Rios  05/11/2015    9      H
# ...

# %%
df.loc[
    (df["programa"] == "Doctorado en Ciencia de Materiales") & (df["apellido_paterno"] == "Hernández"),
    ["id", "matrícula", "nombre", "apellido_paterno", "apellido_materno", "programa"]
]
# Out:
#         id   matrícula           nombre apellido_paterno apellido_materno  \
# 1789  1886  DCM1701004        Elizabeth        Hernández        Francisco
# 1886  1992  DCM1709020            Jaime        Hernández           Rivera
# 1953  2059  DCM1803009  Blanca Cristina        Hernández          Majalca
# 2032  2140  DCM1809020  Sonia Estefanía        Hernández          Sánchez
# 2464  2662  DCM2202004           Javier        Hernández           Rivera
# 2537  2799  DCM2208017  Osniel de Jesús        Hernández          Lartiga
#
#                                 programa
# 1789  Doctorado en Ciencia de Materiales
# 1886  Doctorado en Ciencia de Materiales
# 1953  Doctorado en Ciencia de Materiales
# 2032  Doctorado en Ciencia de Materiales
# 2464  Doctorado en Ciencia de Materiales
# 2537  Doctorado en Ciencia de Materiales
